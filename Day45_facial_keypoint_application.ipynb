# %% [markdown]
# <a href="https://colab.research.google.com/github/yiruchen1993/1st-DL-CVMarathon/blob/feature%2Fdaily_learning/Day45_facial_keypoint_application.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### 範例
# 接下來的程式碼會示範如何在檢測到人臉關鍵點的情況下，做出給人臉戴上太陽眼鏡的濾鏡效果

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2
# %matplotlib inline

# %%
# 使用 colab 環境的同學請執行以下程式碼
# %tensorflow_version 1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2
# import tensorflow as tf
# print(tf.__version__)

import os
from google.colab import drive 
drive.mount('/content/gdrive') # 將 google drive 掛載在 colob，
# Out:
# Mounted at /content/gdrive

# %%
# %cd '/content/gdrive/My Drive/study/DL_CV/'
# Out:
# /content/gdrive/My Drive/study/DL_CV

# %%
# 如果要使用 kaggle API 下載資料的話，請用以下程式碼
os.environ['KAGGLE_USERNAME'] = "yiruchen1993" # 請按照 Day42 簡報內容，獲取 kaggle api 需要用到的 username
os.environ['KAGGLE_KEY'] = "d156daca72dfc25bdf525af1a54b60a8" # 請按照 Day42 簡報獲取 kaggle api 需要用到的 key
# !kaggle competitions download -c facial-keypoints-detection
# !unzip facial-keypoints-detection.zip
# !unzip test.zip
# !unzip training.zip
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.5.6 / client 1.5.4)
# SampleSubmission.csv: Skipping, found more recently modified local copy (use --force to force download)
# test.zip: Skipping, found more recently modified local copy (use --force to force download)
# training.zip: Skipping, found more recently modified local copy (use --force to force download)
# IdLookupTable.csv: Skipping, found more recently modified local copy (use --force to force download)
# unzip:  cannot find or open facial-keypoints-detection.zip, facial-keypoints-detection.zip.zip or facial-keypoints-detection.zip.ZIP.
# Archive:  test.zip
# replace test.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: test.csv
# Archive:  training.zip
# replace training.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: training.csv

# %%
# 讀取資料集以及做前處理的函數
def load_data(dirname):
    # 讀取 csv 文件
    data = pd.read_csv(dirname)
    # 過濾有缺失值的 row
    data = data.dropna()

    # 將圖片像素值讀取為 numpy array 的形態
    data['Image'] = data['Image'].apply(lambda img: np.fromstring(img, sep=' ')).values 

    # 單獨把圖像 array 抽取出來
    imgs = np.vstack(data['Image'].values)/255
    # reshape 為 96 x 96
    imgs = imgs.reshape(data.shape[0], 96, 96)
    # 轉換為 float
    imgs = imgs.astype(np.float32)
    
    # 提取坐標的部分
    points = data[data.columns[:-1]].values

    # 轉換為 float
    points = points.astype(np.float32)

    # normalize 坐標值到 [-0.5, 0.5]
    points = points/96 - 0.5
    
    return imgs, points

# %%
# 讀取資料
imgs_train, points_train = load_data(dirname = 'training.csv')

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

# %%
# 回傳定義好的 model 的函數
def get_model():
    # 定義人臉關鍵點檢測網路
    model = Sequential()

    # 定義神經網路的輸入
    model.add(Conv2D(filters=16, kernel_size=3, activation='relu', input_shape=(96, 96, 1)))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=32, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=64, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=128, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))

    # 最後輸出 30 維的向量，也就是 15 個關鍵點的值
    model.add(Dense(30))
    return model

# %%
model = get_model()
# 配置 loss funtion 和 optimizer
model.compile(loss='mean_squared_error', optimizer='adam')

from keras.callbacks import ModelCheckpoint, History
# model checkpoint 
checkpoint = ModelCheckpoint('best_weights.h5', verbose=1, save_best_only=True)
hist = History()

# training the model
hist_model = model.fit(imgs_train.reshape(-1, 96, 96, 1), 
                       points_train, 
                       validation_split=0.2, batch_size=64, callbacks=[checkpoint, hist],
                       shuffle=True, epochs=50, verbose=1)
# save the model weights
model.save_weights('weights.h5')
# Out:
# Epoch 1/50
# 27/27 [==============================] - ETA: 0s - loss: 0.0084
# Epoch 00001: val_loss improved from inf to 0.00260, saving model to best_weights.h5
# 27/27 [==============================] - 1s 44ms/step - loss: 0.0084 - val_loss: 0.0026
# Epoch 2/50
# 26/27 [===========================>..] - ETA: 0s - loss: 0.0021
# Epoch 00002: val_loss improved from 0.00260 to 0.00198, saving model to best_weights.h5
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0021 - val_loss: 0.0020
# Epoch 3/50
# 22/27 [=======================>......] - ETA: 0s - loss: 0.0015
# Epoch 00003: val_loss improved from 0.00198 to 0.00191, saving model to best_weights.h5
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0015 - val_loss: 0.0019
# Epoch 4/50
# 22/27 [=======================>......] - ETA: 0s - loss: 0.0013
# Epoch 00004: val_loss improved from 0.00191 to 0.00189, saving model to best_weights.h5
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0013 - val_loss: 0.0019
# Epoch 5/50
# 22/27 [=======================>......] - ETA: 0s - loss: 0.0012
# Epoch 00005: val_loss improved from 0.00189 to 0.00189, saving model to best_weights.h5
# 27/27 [==============================] - 0s 16ms/step - loss: 0.0012 - val_loss: 0.0019
# Epoch 6/50
# 25/27 [==========================>...] - ETA: 0s - loss: 0.0011
# Epoch 00006: val_loss did not improve from 0.00189
# 27/27 [==============================] - 0s 11ms/step - loss: 0.0011 - val_loss: 0.0019
# Epoch 7/50
# 23/27 [========================>.....] - ETA: 0s - loss: 0.0010
# Epoch 00007: val_loss improved from 0.00189 to 0.00182, saving model to best_weights.h5
# 27/27 [==============================] - 0s 16ms/step - loss: 0.0010 - val_loss: 0.0018
# Epoch 8/50
# 26/27 [===========================>..] - ETA: 0s - loss: 8.9880e-04
# Epoch 00008: val_loss improved from 0.00182 to 0.00170, saving model to best_weights.h5
# 27/27 [==============================] - 0s 17ms/step - loss: 8.9847e-04 - val_loss: 0.0017
# Epoch 9/50
# 26/27 [===========================>..] - ETA: 0s - loss: 7.9946e-04
# Epoch 00009: val_loss improved from 0.00170 to 0.00158, saving model to best_weights.h5
# 27/27 [==============================] - 1s 19ms/step - loss: 7.9503e-04 - val_loss: 0.0016
# Epoch 10/50
# 26/27 [===========================>..] - ETA: 0s - loss: 7.1695e-04
# Epoch 00010: val_loss improved from 0.00158 to 0.00142, saving model to best_weights.h5
# 27/27 [==============================] - 0s 18ms/step - loss: 7.1677e-04 - val_loss: 0.0014
# Epoch 11/50
# 26/27 [===========================>..] - ETA: 0s - loss: 6.5131e-04
# Epoch 00011: val_loss improved from 0.00142 to 0.00134, saving model to best_weights.h5
# 27/27 [==============================] - 1s 20ms/step - loss: 6.4938e-04 - val_loss: 0.0013
# Epoch 12/50
# 23/27 [========================>.....] - ETA: 0s - loss: 6.1343e-04
# Epoch 00012: val_loss improved from 0.00134 to 0.00124, saving model to best_weights.h5
# 27/27 [==============================] - 0s 15ms/step - loss: 6.0234e-04 - val_loss: 0.0012
# Epoch 13/50
# 24/27 [=========================>....] - ETA: 0s - loss: 5.5644e-04
# Epoch 00013: val_loss improved from 0.00124 to 0.00117, saving model to best_weights.h5
# 27/27 [==============================] - 0s 18ms/step - loss: 5.4638e-04 - val_loss: 0.0012
# Epoch 14/50
# 26/27 [===========================>..] - ETA: 0s - loss: 4.9478e-04
# Epoch 00014: val_loss improved from 0.00117 to 0.00112, saving model to best_weights.h5
# 27/27 [==============================] - 0s 18ms/step - loss: 4.9633e-04 - val_loss: 0.0011
# Epoch 15/50
# 24/27 [=========================>....] - ETA: 0s - loss: 5.1120e-04
# Epoch 00015: val_loss improved from 0.00112 to 0.00104, saving model to best_weights.h5
# 27/27 [==============================] - 0s 18ms/step - loss: 5.0343e-04 - val_loss: 0.0010
# Epoch 16/50
# 22/27 [=======================>......] - ETA: 0s - loss: 4.4004e-04
# Epoch 00016: val_loss improved from 0.00104 to 0.00100, saving model to best_weights.h5
# 27/27 [==============================] - 1s 19ms/step - loss: 4.3771e-04 - val_loss: 0.0010
# Epoch 17/50
# 27/27 [==============================] - ETA: 0s - loss: 4.1426e-04
# Epoch 00017: val_loss improved from 0.00100 to 0.00097, saving model to best_weights.h5
# 27/27 [==============================] - 0s 18ms/step - loss: 4.1426e-04 - val_loss: 9.7224e-04
# Epoch 18/50
# 26/27 [===========================>..] - ETA: 0s - loss: 3.9897e-04
# Epoch 00018: val_loss improved from 0.00097 to 0.00095, saving model to best_weights.h5
# 27/27 [==============================] - 0s 16ms/step - loss: 3.9867e-04 - val_loss: 9.5273e-04
# Epoch 19/50
# 23/27 [========================>.....] - ETA: 0s - loss: 3.9680e-04
# Epoch 00019: val_loss improved from 0.00095 to 0.00095, saving model to best_weights.h5
# 27/27 [==============================] - 0s 18ms/step - loss: 3.9225e-04 - val_loss: 9.4549e-04
# Epoch 20/50
# 22/27 [=======================>......] - ETA: 0s - loss: 3.6851e-04
# Epoch 00020: val_loss improved from 0.00095 to 0.00090, saving model to best_weights.h5
# 27/27 [==============================] - 1s 19ms/step - loss: 3.6418e-04 - val_loss: 9.0322e-04
# Epoch 21/50
# 27/27 [==============================] - ETA: 0s - loss: 3.4922e-04
# Epoch 00021: val_loss improved from 0.00090 to 0.00089, saving model to best_weights.h5
# 27/27 [==============================] - 0s 17ms/step - loss: 3.4922e-04 - val_loss: 8.8545e-04
# Epoch 22/50
# 22/27 [=======================>......] - ETA: 0s - loss: 3.3666e-04
# Epoch 00022: val_loss improved from 0.00089 to 0.00088, saving model to best_weights.h5
# 27/27 [==============================] - 0s 18ms/step - loss: 3.3432e-04 - val_loss: 8.7621e-04
# Epoch 23/50
# 27/27 [==============================] - ETA: 0s - loss: 3.2836e-04
# Epoch 00023: val_loss improved from 0.00088 to 0.00086, saving model to best_weights.h5
# 27/27 [==============================] - 0s 18ms/step - loss: 3.2836e-04 - val_loss: 8.6437e-04
# Epoch 24/50
# 27/27 [==============================] - ETA: 0s - loss: 3.2208e-04
# Epoch 00024: val_loss did not improve from 0.00086
# 27/27 [==============================] - 0s 12ms/step - loss: 3.2208e-04 - val_loss: 8.9970e-04
# Epoch 25/50
# 22/27 [=======================>......] - ETA: 0s - loss: 3.1292e-04
# Epoch 00025: val_loss improved from 0.00086 to 0.00085, saving model to best_weights.h5
# 27/27 [==============================] - 0s 15ms/step - loss: 3.1125e-04 - val_loss: 8.4841e-04
# Epoch 26/50
# 23/27 [========================>.....] - ETA: 0s - loss: 2.9599e-04
# Epoch 00026: val_loss did not improve from 0.00085
# 27/27 [==============================] - 0s 11ms/step - loss: 2.9742e-04 - val_loss: 8.5619e-04
# Epoch 27/50
# 22/27 [=======================>......] - ETA: 0s - loss: 2.8697e-04
# Epoch 00027: val_loss did not improve from 0.00085
# 27/27 [==============================] - 0s 11ms/step - loss: 2.8967e-04 - val_loss: 8.6515e-04
# Epoch 28/50
# 22/27 [=======================>......] - ETA: 0s - loss: 2.8799e-04
# Epoch 00028: val_loss did not improve from 0.00085
# 27/27 [==============================] - 0s 11ms/step - loss: 2.8652e-04 - val_loss: 8.6308e-04
# Epoch 29/50
# 23/27 [========================>.....] - ETA: 0s - loss: 2.8716e-04
# Epoch 00029: val_loss improved from 0.00085 to 0.00082, saving model to best_weights.h5
# 27/27 [==============================] - 0s 15ms/step - loss: 2.8462e-04 - val_loss: 8.2431e-04
# Epoch 30/50
# 23/27 [========================>.....] - ETA: 0s - loss: 2.7135e-04
# Epoch 00030: val_loss did not improve from 0.00082
# 27/27 [==============================] - 0s 11ms/step - loss: 2.7622e-04 - val_loss: 8.3491e-04
# Epoch 31/50
# 26/27 [===========================>..] - ETA: 0s - loss: 2.6919e-04
# Epoch 00031: val_loss did not improve from 0.00082
# 27/27 [==============================] - 0s 12ms/step - loss: 2.6852e-04 - val_loss: 8.5023e-04
# Epoch 32/50
# 22/27 [=======================>......] - ETA: 0s - loss: 2.5591e-04
# Epoch 00032: val_loss did not improve from 0.00082
# 27/27 [==============================] - 0s 11ms/step - loss: 2.5998e-04 - val_loss: 8.3477e-04
# Epoch 33/50
# 26/27 [===========================>..] - ETA: 0s - loss: 2.5656e-04
# Epoch 00033: val_loss did not improve from 0.00082
# 27/27 [==============================] - 0s 12ms/step - loss: 2.5551e-04 - val_loss: 8.5289e-04
# Epoch 34/50
# 26/27 [===========================>..] - ETA: 0s - loss: 2.4981e-04
# Epoch 00034: val_loss did not improve from 0.00082
# 27/27 [==============================] - 0s 11ms/step - loss: 2.4997e-04 - val_loss: 8.5562e-04
# Epoch 35/50
# 26/27 [===========================>..] - ETA: 0s - loss: 2.4962e-04
# Epoch 00035: val_loss did not improve from 0.00082
# 27/27 [==============================] - 0s 11ms/step - loss: 2.5102e-04 - val_loss: 8.4254e-04
# Epoch 36/50
# 26/27 [===========================>..] - ETA: 0s - loss: 2.4802e-04
# Epoch 00036: val_loss did not improve from 0.00082
# 27/27 [==============================] - 0s 12ms/step - loss: 2.4882e-04 - val_loss: 8.3869e-04
# Epoch 37/50
# 23/27 [========================>.....] - ETA: 0s - loss: 2.5260e-04
# Epoch 00037: val_loss did not improve from 0.00082
# 27/27 [==============================] - 0s 11ms/step - loss: 2.4981e-04 - val_loss: 8.7554e-04
# Epoch 38/50
# 22/27 [=======================>......] - ETA: 0s - loss: 2.3366e-04
# Epoch 00038: val_loss did not improve from 0.00082
# 27/27 [==============================] - 0s 11ms/step - loss: 2.3528e-04 - val_loss: 8.2487e-04
# Epoch 39/50
# 24/27 [=========================>....] - ETA: 0s - loss: 2.3810e-04
# Epoch 00039: val_loss improved from 0.00082 to 0.00078, saving model to best_weights.h5
# 27/27 [==============================] - 0s 15ms/step - loss: 2.3747e-04 - val_loss: 7.7772e-04
# Epoch 40/50
# 22/27 [=======================>......] - ETA: 0s - loss: 2.2719e-04
# Epoch 00040: val_loss did not improve from 0.00078
# 27/27 [==============================] - 0s 11ms/step - loss: 2.2775e-04 - val_loss: 7.9950e-04
# Epoch 41/50
# 24/27 [=========================>....] - ETA: 0s - loss: 2.2219e-04
# Epoch 00041: val_loss did not improve from 0.00078
# 27/27 [==============================] - 0s 11ms/step - loss: 2.2348e-04 - val_loss: 8.1609e-04
# Epoch 42/50
# 25/27 [==========================>...] - ETA: 0s - loss: 2.1693e-04
# Epoch 00042: val_loss did not improve from 0.00078
# 27/27 [==============================] - 0s 11ms/step - loss: 2.1624e-04 - val_loss: 8.5448e-04
# Epoch 43/50
# 23/27 [========================>.....] - ETA: 0s - loss: 2.1236e-04
# Epoch 00043: val_loss improved from 0.00078 to 0.00077, saving model to best_weights.h5
# 27/27 [==============================] - 0s 15ms/step - loss: 2.1236e-04 - val_loss: 7.7143e-04
# Epoch 44/50
# 23/27 [========================>.....] - ETA: 0s - loss: 2.1570e-04
# Epoch 00044: val_loss did not improve from 0.00077
# 27/27 [==============================] - 0s 11ms/step - loss: 2.1332e-04 - val_loss: 7.7990e-04
# Epoch 45/50
# 26/27 [===========================>..] - ETA: 0s - loss: 2.0996e-04
# Epoch 00045: val_loss did not improve from 0.00077
# 27/27 [==============================] - 0s 12ms/step - loss: 2.1087e-04 - val_loss: 8.0846e-04
# Epoch 46/50
# 22/27 [=======================>......] - ETA: 0s - loss: 1.9896e-04
# Epoch 00046: val_loss did not improve from 0.00077
# 27/27 [==============================] - 0s 11ms/step - loss: 1.9990e-04 - val_loss: 8.1120e-04
# Epoch 47/50
# 24/27 [=========================>....] - ETA: 0s - loss: 2.0807e-04
# Epoch 00047: val_loss did not improve from 0.00077
# 27/27 [==============================] - 0s 11ms/step - loss: 2.0543e-04 - val_loss: 8.1653e-04
# Epoch 48/50
# 23/27 [========================>.....] - ETA: 0s - loss: 2.0311e-04
# Epoch 00048: val_loss did not improve from 0.00077
# 27/27 [==============================] - 0s 11ms/step - loss: 2.0274e-04 - val_loss: 7.8326e-04
# Epoch 49/50
# 23/27 [========================>.....] - ETA: 0s - loss: 1.9787e-04
# Epoch 00049: val_loss did not improve from 0.00077
# 27/27 [==============================] - 0s 11ms/step - loss: 2.0083e-04 - val_loss: 8.0182e-04
# Epoch 50/50
# 23/27 [========================>.....] - ETA: 0s - loss: 2.0380e-04
# Epoch 00050: val_loss did not improve from 0.00077
# 27/27 [==============================] - 0s 11ms/step - loss: 2.0317e-04 - val_loss: 8.1186e-04

# %%
# model = get_model()
# model.load_weights("best_weights.h5") # 載入之前 train 好的權重

# %%
sample_img = imgs_train[0] # 選一張圖片做人臉濾鏡的樣本
sample_point = points_train[0]
# 在灰階圖像上畫關鍵點的函數
def plot_keypoints(img, points):
    plt.imshow(img, cmap='gray')
    for i in range(0,30,2):
        plt.scatter((points[i] + 0.5)*96, (points[i+1]+0.5)*96, color='red')
        plt.text((points[i] + 0.5)*96, (points[i+1]+0.5-0.05)*96, str(int(i/2))) # 把關鍵點 index 畫出來

# %%
plot_keypoints(sample_img, sample_point)

# %% [markdown]
# 在我們應用人臉關鍵點時，不管資料集文件沒有寫清楚，都可以通過把 index 畫出來的方式來理解關鍵點的順序。

# %%
sunglasses = cv2.imread('sunglasses.png', cv2.IMREAD_UNCHANGED) # cv2.IMREAD_UNCHANGED 表示要讀取圖像透明度的 channel
plt.imshow(sunglasses)

# %% [markdown]
# 接下來我們利用預測到的人臉關鍵點信息，把這個太陽眼鏡放到 sample_img 上
#
# **Note**: 這個太陽眼鏡的圖片必須是透明背景的 .png 哦，有興趣的同學也可以拿非透明背景的圖片來試看有什麼分別...

# %%
landmarks = model.predict(sample_img.reshape(-1, 96, 96, 1)) # 預測人臉關鍵點
landmarks = (landmarks + 0.5) * 96 # 將預測的人臉關鍵點的數值範圍由 -0.5 ~ 0.5 轉回 0 ~ 96
key_pts = landmarks.reshape(-1, 2)

face_img = cv2.cvtColor((sample_img*255).astype(np.uint8), cv2.COLOR_GRAY2BGR) # 將灰階圖像轉為 BGR

# 以下示範如何用檢測到的關鍵點去定義要增加太陽眼鏡濾鏡的坐標，
# 其中使用的 key_pts index 就是由 plot_keypoints 所畫出來的 index 觀察而來
sunglass_top_x = int(key_pts[9, 0]) # 在這裡選右眉毛的最外側 (也就是第 9 index) 做太陽眼鏡的最左邊
sunglass_w = int(abs(key_pts[9, 0] - key_pts[7, 0])) # 在這裡選右眉毛最外側到左眉毛最外側 (也就是第 7、9 index) 做為太陽眼鏡的寬
sunglass_top_y = int((key_pts[9, 1] + key_pts[5, 1]) / 2) # y 和 h 也是類似的道理了
sunglass_h = int(abs(key_pts[8, 1] - key_pts[10, 1]) / 2)

new_sunglasses =  cv2.resize(sunglasses, (sunglass_w, sunglass_h), interpolation = cv2.INTER_CUBIC)

# roi 為要覆蓋太陽眼鏡的 BGR 人臉範圍
roi = face_img[sunglass_top_y:sunglass_top_y+sunglass_h, sunglass_top_x:sunglass_top_x+sunglass_w]

# 找出非透明的 pixel
ind = np.argwhere(new_sunglasses[:,:,3] > 0)

# 把 roi 中每個 channel 非透明的地方替換為太陽眼鏡的 pixel
for i in range(3):
    roi[ind[:,0],ind[:,1],i] = new_sunglasses[ind[:,0],ind[:,1],i]

# %%
plt.imshow(face_img)

# %% [markdown]
# 如此就完成一個簡單的太陽眼鏡人臉濾鏡啦！
#
# 實際應用中，人臉關鍵點檢測只是其實一個環節，要做到應用級別，至少還需要一個人臉檢測模型
#
# 而人臉相關的應用算是相對比較成熟的領域，所以可以找到很多研究和開源代碼，本課程有推薦一些項目，有興趣的同學可以自行參考～
